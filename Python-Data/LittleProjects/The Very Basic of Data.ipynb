# %% [markdown]
# # My first time
# This is the first time I tried delving itnto data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv(r"C:\Users\magan\Desktop\Python-Courses\Python-Data\HousePrices.csv")
print(df)
x = np.array(df["Sq Meters"].tolist())
y = np.array(df["Prices in Hundred K"].tolist())
# Out:
#    Sq Meters  Prices in Hundred K
# 0         23                  194
# 1         18                  110
# 2         14                  103
# 3         12                  134
# 4         24                  175
# 5         18                  132
# 6         10                  140
# 7         22                  101
# 8         11                  146
# 9         20                  120

# %% [markdown]
# You can see here that there's a problem with the data I produced. As it is random, it is not guaranteed that there's a linear relationship betweeen the Sq Meters column and the Prices in Hundred K column.

# %%
plt.scatter(x, y)
plt.show()

# %%
# making test, train and all those things:
xTrain, xTest, yTrain, yTest = train_test_split(x, y, train_size = 0.8, test_size = 0.2)

# %%
plt.scatter(xTrain, yTrain)
plt.show()

# %%
plt.scatter(xTest, yTest)
plt.show()
